# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
#Load model parameters
model = torch.load('model.pt', weights_only=False)
model.eval()
# Out:
# SindyAutoEncoder(
#   (encoder_layers): ModuleList(
#     (0): Linear(in_features=9409, out_features=4800, bias=True)
#     (1): Linear(in_features=4800, out_features=2400, bias=True)
#     (2): Linear(in_features=2400, out_features=1200, bias=True)
#     (3): Linear(in_features=1200, out_features=600, bias=True)
#     (4): Linear(in_features=600, out_features=200, bias=True)
#     (5): Linear(in_features=200, out_features=40, bias=True)
#     (6): Linear(in_features=40, out_features=1, bias=True)
#   )
#   (decoder_layers): ModuleList(
#     (0): Linear(in_features=1, out_features=40, bias=True)
#     (1): Linear(in_features=40, out_features=200, bias=True)
#     (2): Linear(in_features=200, out_features=600, bias=True)
#     (3): Linear(in_features=600, out_features=1200, bias=True)
#     (4): Linear(in_features=1200, out_features=2400, bias=True)
#     (5): Linear(in_features=2400, out_features=4800, bias=True)
#     (6): Linear(in_features=4800, out_features=9409, bias=True)
# ...

# %%
# Read training data
t_train = []
train_losses = []
with open('train_data/train_losses.dat', 'r') as f:
    for line in f:
        v = list(map(float, line.split()))
        t_train.append(v[0])
        train_losses.append(v[1])
t_test = []
test_losses = []
with open('train_data/test_losses.dat', 'r') as f:
    for line in f:
        v = list(map(float, line.split()))
        t_test.append(v[0])
        test_losses.append(v[1])

# %%
plt.plot(t_train[100:],train_losses[100:],zorder=5)
plt.scatter(t_test[10:],test_losses[10:],color='r',zorder=15)
plt.style.use('fivethirtyeight')
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
t_train = []
sindy_weights = [[] for i in range(10)]
with open('train_data/sindy_weights.dat', 'r') as f:
    for line in f:
        v = list(map(float, line.split()))
        t_train.append(v[0])
        for i in range(1,len(v)):
            sindy_weights[i-1].append(v[i])

# %%
for i in range(10):
    plt.plot(t_train,sindy_weights[i])
plt.xlabel('Iterations')
plt.ylabel('sindy_weight')
# Out:
# Text(0, 0.5, 'sindy_weight')
